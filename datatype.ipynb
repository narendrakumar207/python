# %%
#access vlaue in a tuple
student = ("narendra kumar",21,85.5)

print(student(0))
print(student(1))

# %%
student = ("narendrakumar",21,85.5)
student(1) = 22
#this gives an error because we cannot modify a tuple

# %%
#tuple are imutable. meaning they cannot be changed after created 
numbers = (10,20,20,30,20) 
print(numbers.count(20))

# %%
numbers = (10,20,30,40)

print(number.index(30))

# %%
numbers = (10,20,30,40)

print(len(numbers))
print(max(numbers))
print(min(numbers))
print(sum(numbers))

# %%
#set in python
#set is a collection of unique values that is unordered and mutable 
numbers = {10,20,30,20,10}
print(numbers)

# %%
#add values to a set 
subjects = {"python", "java"}

subjects.add("SQL")

print(subjects)

# %%
#remove values from a set 
subjects.remove("java")

print(subjects)

# %%
#set do not allow duplicate values
numbers = {1, 2, 2, 3, 3, 4}

print(numbers)

# %%
#dictionaries in python
#Dictionaries is a collection of key value pairs that is unordered
student = {
    "name": "narendra kumar",
    "age" : "19",
    "course": "python"
}
print(student)

# %%
#access elements in dic
print(student["name"])
print(student["age"])
print(student["course"])

# %%
#add new data to a dictionary 
student ["city"] = "tirupathi"

print(student)

# %%
print(student.keys()) 
# keys() returns a view object that displays a list of all the keys in the dictionary.
print(student.values()) 
# values() returns all the values in the dictionary.
print(student.items()) 
# items() returns all key-value pairs.
print(student.get("name")) 
# get() returns the value for the specified key 
student.update({"age": 20}) 
# update() updates the value for the specified key.
print(student)
student.pop("age")
#pop() removes the specified key and its corresponding value from the dictionary.

print(student)

# %%
#popitem() removes the last inserted key-value pair
student = {
    "name": "narendra kumar",
    "age" : "19",
    "course": "python"
}
student.popitem()
print(student)

# %%
student = {
    "name": "narendra kumar",
}
student.setdefault("age", 19)

 print(student)
