# %%
number = int(input("enter a number;"))
if number %5 == 0:
 print("divisible by 5")

# %%
marks = int(input("enter marks:"))

if marks >= 40:
    print("pass")
else:
    print("fail")

# %%
number=int(input("enter a number"))
if number>=0:
    print("position")
else:
    print("negation")

# %%
number = int(input("enter a number:"))

if number > 100:
        print("number is greater than 100")
    else:
        print("number is not greater than 100")

# %%
marks = int(input("entermarks"))

if marks >= 90:
    print("grade A")
elif marks >=75:
    print("grade B")
elif marks >=60:
     print("grade C")
elif marks >=40:
    print("grade D")
else:
    print("fail")
# Out:
# grade A

# %%
a =  int (input("enter first number"))
b =  int (input("enter second number"))

if a > b:
    print("lagest:",a)
elif b > a:
    print("largest:",b)
else:
    print("both are equal")

# %%
a = int(input("enter first number:"))
b = int(input("enter second number:"))
c = int(input("enter third number:"))

if a >= b and a >=c:
    print("largest:",a)
elif b >= c and b >=c:
    print("largest:",b)
else 
    print("largest:",c)

# %%
number = int (input("enter a number"))

if number >0:
    print("positive")
elif number <0:
    print("negative")
else:
    print("zero")

# %%
day =  int (input("enter day number"))

if day ==1:
    print("monday")
elif day ==2:
    print("tuesday")
elif day ==3:
    print("wednesday")
elif day ==4:
    print("thursday")
elif day ==5:
    print("friday")
elif day ==6:
    print("saturday")
elif day ==7:
    print("sunday")
else:
    print("invalid syntax")

# %%
a = float(input("enter first number:"))
b = float(input("enter second number:"))
operates = input("enter operates(+,-,*,/):")

if operater == "+":
    print("result:", a+b)
elif operater == "-":
    print("result:", a-b)
elif operator == "*":
    print("result:",a*b)
elif operator == "/":
    if  b !=0:
        print("Result:", a/ b)
    else:
        print("connot divide by zero")
else:
        print("invalid operator")

# %%
username = input("enter a username: ")
password = input("enter a password: ")

if username == "narendra kumar":
    if password == "2007":
        print("login successfully")
    else:
        print("wrong password")
else:
    print("wrong username")

# %%
balance = float (input("enter balance:"))
amount = float (input("enter withdrawal amount:"))

if amount > 0:
    if amount<=balance:
        balance - amount
        print("withdrawal successful")
        print("remainig balance:", balance)
    else:
        print("insffivent balance")
else:
    print("invail amount")

# %%
marks= int(input("enter marks:"))
attendance= int(input("enter attendace percentage:"))

if marks >=40:
    if attendance >=75:
        print("eligible")
    else:
        print("not eligible due to attendance")
else:
    print("not eligible due to marks")
# Out:
# egible

# %%
age = int (input("enter a age:"))
test = input("did you pass the driving test?(yes or no):")

if age >=18:
    if test =="yes":
        print("license can be issued")
    else:
        print("pass the driving test first")
else:
    print("not eligible due to age")
# Out:
# license can be issued

# %%
print(2+13*2)
# Out:
# 28

# %%
result= (10+5) *2

print(result)
# Out:
# 30
